# %%
import torch
import torchaudio

print(torch.__version__)
print(torchaudio.__version__)

torch.random.manual_seed(0)
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:   
    device = torch.device("cpu")
print("Using device:")

print(device)
# Out:
# 2.6.0.dev20241112
# 2.5.0.dev20241118
# Using device:
# mps

# %%
import IPython
import matplotlib.pyplot as plt
from torchaudio.utils import download_asset

SPEECH_FILE = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
SPEECH_FILE
# Out:
# 100%|██████████| 106k/106k [00:00<00:00, 39.3MB/s]
# '/Users/rishidwd29/.cache/torch/hub/torchaudio/tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav'

# %%
bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H

print("Sample Rate:", bundle.sample_rate)

print("Labels:", bundle.get_labels())
# Out:
# Sample Rate: 16000
# Labels: ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')

# %%
model = bundle.get_model().to(device)

print(model.__class__)
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /Users/rishidwd29/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# 100%|██████████| 360M/360M [00:28<00:00, 13.1MB/s]
# <class 'torchaudio.models.wav2vec2.model.Wav2Vec2Model'>
